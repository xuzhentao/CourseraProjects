# %% [markdown]
# # Programming Assignment

# %% [markdown]
# ## Data pipeline with Keras and tf.data

# %% [markdown]
# ### Instructions
#
# In this notebook, you will implement a data processing pipeline using tools from both Keras and the tf.data module. You will use the `ImageDataGenerator` class in the tf.keras module to feed a network with training and test images from a local directory containing a subset of the LSUN dataset, and train the model both with and without data augmentation. You will then use the `map` and `filter` functions of the `Dataset` class with the CIFAR-100 dataset to train a network to classify a processed subset of the images.
#
# Some code cells are provided you in the notebook. You should avoid editing provided code, and make sure to execute the cells in order to avoid unexpected errors. Some cells begin with the line:
#
# `#### GRADED CELL ####`
#
# Don't move or edit this first line - this is what the automatic grader looks for to recognise graded cells. These cells require you to write your own code to complete them, and are automatically graded when you submit the notebook. Don't edit the function name or signature provided in these cells, otherwise the automatic grader might not function properly. Inside these graded cells, you can use any functions or classes that are imported below, but make sure you don't use any variables that are outside the scope of the function.
#
# ### How to submit
#
# Complete all the tasks you are asked for in the worksheet. When you have finished and are happy with your code, press the **Submit Assignment** button at the top of this notebook.
#
# ### Let's get started!
#
# We'll start running some imports, and loading the dataset. Do not edit the existing imports in the following cell. If you would like to make further Tensorflow imports, you should add them here.

# %%
#### PACKAGE IMPORTS ####

# Run this cell first to import all required packages. Do not make any imports elsewhere in the notebook

import tensorflow as tf
from tensorflow.keras.datasets import cifar100
import numpy as np
import matplotlib.pyplot as plt
import json
# %matplotlib inline

# If you would like to make further imports from tensorflow, add them here

# %% [markdown]
# ### Part 1: tf.keras
# <table><tr>
# <td> <img src="data/lsun/church.png" alt="Church" style="height: 210px;"/>  </td>
# <td> <img src="data/lsun/classroom.png" alt="Classroom" style="height: 210px;"/> </td>
#     <td> <img src="data/lsun/conference_room.png" alt="Conference Room" style="height: 210px;"/> </td>
# </tr></table>
#
# #### The LSUN Dataset
#
# In the first part of this assignment, you will use a subset of the [LSUN dataset](https://www.yf.io/p/lsun). This is a large-scale image dataset with 10 scene and 20 object categories. A subset of the LSUN dataset has been provided, and has already been split into training and test sets. The three classes included in the subset are `church_outdoor`, `classroom` and `conference_room`.
#
# * F. Yu, A. Seff, Y. Zhang, S. Song, T. Funkhouser and J. Xia. "LSUN: Construction of a Large-scale Image Dataset using Deep Learning with Humans in the Loop". arXiv:1506.03365, 10 Jun 2015
#
# Your goal is to use the Keras preprocessing tools to construct a data ingestion and augmentation pipeline to train a neural network to classify the images into the three classes.

# %%
# Save the directory locations for the training, validation and test sets

train_dir = 'data/lsun/train'
valid_dir = 'data/lsun/valid'
test_dir = 'data/lsun/test'

# %% [markdown]
# #### Create a data generator using the ImageDataGenerator class

# %% [markdown]
# You should first write a function that creates an `ImageDataGenerator` object, which rescales the image pixel values by a factor of 1/255.

# %%
#### GRADED CELL ####

# Complete the following function. 
# Make sure to not change the function name or arguments.

def get_ImageDataGenerator():
    """
    This function should return an instance of the ImageDataGenerator class.
    This instance should be set up to rescale the data with the above scaling factor.
    """
    from tensorflow.keras.preprocessing.image import ImageDataGenerator  
    return ImageDataGenerator(rescale = 1.0/255)

# %%
# Call the function to get an ImageDataGenerator as specified

image_gen = get_ImageDataGenerator()

# %% [markdown]
# You should now write a function that returns a generator object that will yield batches of images and labels from the training and test set directories. The generators should:
#
# * Generate batches of size 20.
# * Resize the images to 64 x 64 x 3.
# * Return one-hot vectors for labels. These should be encoded as follows:
#     * `classroom` $\rightarrow$ `[1., 0., 0.]`
#     * `conference_room` $\rightarrow$ `[0., 1., 0.]`
#     * `church_outdoor` $\rightarrow$ `[0., 0., 1.]`
# * Pass in an optional random `seed` for shuffling (this should be passed into the `flow_from_directory` method).
#
# **Hint:** you may need to refer to the [documentation](https://keras.io/preprocessing/image/#imagedatagenerator-class) for the `ImageDataGenerator`.

# %%
#### GRADED CELL ####

# Complete the following function.
# Make sure not to change the function name or arguments.



from tensorflow.keras.preprocessing.image import ImageDataGenerator  

    
def get_generator(image_data_generator:ImageDataGenerator, directory, seed=None):
    """
    This function takes an ImageDataGenerator object in the first argument and a 
    directory path in the second argument.
    It should use the ImageDataGenerator to return a generator object according 
    to the above specifications. 
    The seed argument should be passed to the flow_from_directory method.
    """
    classes = ['classroom', 'conference_room', 'church_outdoor']
    
    return image_data_generator.flow_from_directory(directory, classes = classes,batch_size = 20, target_size = (64,64), seed = seed)

# %%
# Run this cell to define training and validation generators

train_generator = get_generator(image_gen, train_dir)
valid_generator = get_generator(image_gen, valid_dir)
# Out:
# Found 300 images belonging to 3 classes.
# Found 120 images belonging to 3 classes.

# %% [markdown]
# We are using a small subset of the dataset for demonstrative purposes in this assignment.

# %% [markdown]
# #### Display sample images and labels from the training set
#
# The following cell depends on your function `get_generator` to be implemented correctly. If it raises an error, go back and check the function specifications carefully.

# %%
# Display a few images and labels from the training set

batch = next(train_generator)
batch_images = np.array(batch[0])
batch_labels = np.array(batch[1])
lsun_classes = ['classroom', 'conference_room', 'church_outdoor']

plt.figure(figsize=(16,10))
for i in range(20):
    ax = plt.subplot(4, 5, i+1)
    plt.imshow(batch_images[i])
#     plt.title(np.where(batch_labels[i] == 1.))
    plt.title(lsun_classes[np.where(batch_labels[i] == 1.)[0][0]])
    plt.axis('off')

# %%
# Reset the training generator

train_generator = get_generator(image_gen, train_dir)
# Out:
# Found 300 images belonging to 3 classes.

# %% [markdown]
# #### Build the neural network model
#
# You will now build and compile a convolutional neural network classifier. Using the functional API, build your model according to the following specifications:
#
# * The model should use the `input_shape` in the function argument to define the Input layer.
# * The first hidden layer should be a Conv2D layer with 8 filters, a 8x8 kernel size.
# * The second hidden layer should be a MaxPooling2D layer with a 2x2 pooling window size.
# * The third hidden layer should be a Conv2D layer with 4 filters, a 4x4 kernel size.
# * The fourth hidden layer should be a MaxPooling2D layer with a 2x2 pooling window size.
# * This should be followed by a Flatten layer, and then a Dense layer with 16 units and ReLU activation.
# * The final layer should be a Dense layer with 3 units and softmax activation.
# * All Conv2D layers should use `"SAME"` padding and a ReLU activation function.
#
# In total, the network should have 8 layers. The model should then be compiled with the Adam optimizer with learning rate 0.0005, categorical cross entropy loss, and categorical accuracy metric.

# %%
#### GRADED CELL ####

# Complete the following function.
# Make sure not to change the function name or arguments.

def get_model(input_shape):
    """
    This function should build and compile a CNN model according to the above specification,
    using the functional API. Your function should return the model.
    """
    from tensorflow.keras.models import Model
    from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Flatten, Dense
    
    input_layer = Input(input_shape)
    l1 = Conv2D(filters = 8, kernel_size = (8,8), padding = "SAME", activation = "relu")(input_layer)
    l1 = MaxPooling2D((2,2))(l1)
    l1 = Conv2D(filters = 4, kernel_size = (4,4), padding = "SAME", activation = "relu")(l1)
    l1 = MaxPooling2D((2,2))(l1)
    l1 = Flatten()(l1)
    l1 = Dense(16, activation = "relu")(l1)
    l1 = Dense(3, activation = "softmax")(l1)
    output_layer = l1
    
    model =  Model(input_layer, output_layer)
    optimizer = tf.keras.optimizers.Adam(learning_rate=0.0005)
    model.compile(optimizer = optimizer, loss = "categorical_crossentropy", metrics = ["categorical_accuracy"])
    return model

# %%
# Build and compile the model, print the model summary

lsun_model = get_model((64, 64, 3))
lsun_model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 64, 64, 3)]       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 64, 64, 8)         1544
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 32, 32, 8)         0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 32, 32, 4)         516
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 16, 16, 4)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 1024)              0
# _________________________________________________________________
# dense (Dense)                (None, 16)                16400
# _________________________________________________________________
# dense_1 (Dense)              (None, 3)                 51
# =================================================================
# Total params: 18,511
# Trainable params: 18,511
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #### Train the neural network model
#
# You should now write a function to train the model for a specified number of epochs (specified in the `epochs` argument). The function takes a `model` argument, as well as `train_gen` and `valid_gen` arguments for the training and validation generators respectively, which you should use for training and validation data in the training run. You should also use the following callbacks:
#
# * An `EarlyStopping` callback that monitors the validation accuracy and has patience set to 10.
# * A `ReduceLROnPlateau` callback that monitors the validation loss and has the factor set to 0.5 and minimum learning set to 0.0001
#
# Your function should return the training history.

# %%
#### GRADED CELL ####

# Complete the following function.
# Make sure not to change the function name or arguments.


def train_model(model, train_gen, valid_gen, epochs):
    """
    This function should define the callback objects specified above, and then use the
    train_gen and valid_gen generator object arguments to train the model for the (maximum) 
    number of epochs specified in the function argument, using the defined callbacks.
    The function should return the training history.
    """
    
    callback_1  = tf.keras.callbacks.EarlyStopping(monitor='val_accuracy', patience=10)
    callback_2 = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.5,min_lr=0.0001)
    return model.fit_generator(train_gen, validation_data = valid_gen, epochs = epochs, callbacks = [callback_1, callback_2])

# %%
# Train the model for (maximum) 50 epochs

history = train_model(lsun_model, train_generator, valid_generator, epochs=50)
# Out:
# Epoch 1/50
# 14/15 [===========================>..] - ETA: 0s - loss: 1.1209 - categorical_accuracy: 0.3071WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 12s 786ms/step - loss: 1.1185 - categorical_accuracy: 0.3167 - val_loss: 1.0951 - val_categorical_accuracy: 0.3000
# Epoch 2/50
# 14/15 [===========================>..] - ETA: 0s - loss: 1.0738 - categorical_accuracy: 0.4214WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 10s 673ms/step - loss: 1.0712 - categorical_accuracy: 0.4267 - val_loss: 1.0636 - val_categorical_accuracy: 0.4000
# Epoch 3/50
# 14/15 [===========================>..] - ETA: 0s - loss: 1.0321 - categorical_accuracy: 0.4500WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 10s 660ms/step - loss: 1.0282 - categorical_accuracy: 0.4600 - val_loss: 1.0209 - val_categorical_accuracy: 0.4750
# Epoch 4/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.9688 - categorical_accuracy: 0.5536WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 10s 660ms/step - loss: 0.9661 - categorical_accuracy: 0.5500 - val_loss: 0.9381 - val_categorical_accuracy: 0.5583
# Epoch 5/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.8812 - categorical_accuracy: 0.6107WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 10s 653ms/step - loss: 0.8712 - categorical_accuracy: 0.6200 - val_loss: 0.8829 - val_categorical_accuracy: 0.5750
# Epoch 6/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.8057 - categorical_accuracy: 0.5929WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 10s 673ms/step - loss: 0.8119 - categorical_accuracy: 0.5967 - val_loss: 0.8813 - val_categorical_accuracy: 0.5417
# Epoch 7/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.7657 - categorical_accuracy: 0.6643WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 10s 667ms/step - loss: 0.7657 - categorical_accuracy: 0.6633 - val_loss: 0.7998 - val_categorical_accuracy: 0.6167
# Epoch 8/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.7076 - categorical_accuracy: 0.7179WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 10s 667ms/step - loss: 0.7143 - categorical_accuracy: 0.7067 - val_loss: 0.7794 - val_categorical_accuracy: 0.6417
# Epoch 9/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.6708 - categorical_accuracy: 0.7107WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 10s 653ms/step - loss: 0.6759 - categorical_accuracy: 0.7033 - val_loss: 0.7527 - val_categorical_accuracy: 0.6667
# Epoch 10/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.6222 - categorical_accuracy: 0.7571WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 10s 660ms/step - loss: 0.6422 - categorical_accuracy: 0.7367 - val_loss: 0.7344 - val_categorical_accuracy: 0.6667
# Epoch 11/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.5843 - categorical_accuracy: 0.7643WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 10s 660ms/step - loss: 0.5935 - categorical_accuracy: 0.7600 - val_loss: 0.8060 - val_categorical_accuracy: 0.6250
# Epoch 12/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.5717 - categorical_accuracy: 0.7821WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 10s 680ms/step - loss: 0.5825 - categorical_accuracy: 0.7733 - val_loss: 0.7263 - val_categorical_accuracy: 0.6667
# Epoch 13/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.5150 - categorical_accuracy: 0.8000WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 10s 660ms/step - loss: 0.5181 - categorical_accuracy: 0.8033 - val_loss: 0.7292 - val_categorical_accuracy: 0.6667
# Epoch 14/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.4879 - categorical_accuracy: 0.8107WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 10s 667ms/step - loss: 0.4872 - categorical_accuracy: 0.8100 - val_loss: 0.7709 - val_categorical_accuracy: 0.6750
# Epoch 15/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.4432 - categorical_accuracy: 0.8214WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 10s 667ms/step - loss: 0.4496 - categorical_accuracy: 0.8167 - val_loss: 0.7539 - val_categorical_accuracy: 0.6583
# Epoch 16/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.4750 - categorical_accuracy: 0.8250WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 10s 667ms/step - loss: 0.4635 - categorical_accuracy: 0.8333 - val_loss: 0.7368 - val_categorical_accuracy: 0.6583
# Epoch 17/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.4471 - categorical_accuracy: 0.8250WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 10s 680ms/step - loss: 0.4385 - categorical_accuracy: 0.8300 - val_loss: 0.7336 - val_categorical_accuracy: 0.6667
# Epoch 18/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.4391 - categorical_accuracy: 0.8214WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 10s 667ms/step - loss: 0.4407 - categorical_accuracy: 0.8167 - val_loss: 0.7836 - val_categorical_accuracy: 0.6750
# Epoch 19/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.4022 - categorical_accuracy: 0.8286WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 10s 647ms/step - loss: 0.4044 - categorical_accuracy: 0.8300 - val_loss: 0.7983 - val_categorical_accuracy: 0.6750
# Epoch 20/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.3493 - categorical_accuracy: 0.8571WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 10s 660ms/step - loss: 0.3610 - categorical_accuracy: 0.8500 - val_loss: 0.8295 - val_categorical_accuracy: 0.6750
# Epoch 21/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.3264 - categorical_accuracy: 0.8857WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 10s 667ms/step - loss: 0.3287 - categorical_accuracy: 0.8867 - val_loss: 0.8059 - val_categorical_accuracy: 0.6750
# Epoch 22/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.3005 - categorical_accuracy: 0.8786WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 10s 660ms/step - loss: 0.3136 - categorical_accuracy: 0.8767 - val_loss: 0.8346 - val_categorical_accuracy: 0.6667
# Epoch 23/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.2888 - categorical_accuracy: 0.9179WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 10s 653ms/step - loss: 0.2828 - categorical_accuracy: 0.9233 - val_loss: 0.8166 - val_categorical_accuracy: 0.6917
# Epoch 24/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.2799 - categorical_accuracy: 0.8893WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 10s 660ms/step - loss: 0.2847 - categorical_accuracy: 0.8867 - val_loss: 0.8297 - val_categorical_accuracy: 0.6750
# Epoch 25/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.2789 - categorical_accuracy: 0.9000WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 10s 660ms/step - loss: 0.2747 - categorical_accuracy: 0.9067 - val_loss: 0.8211 - val_categorical_accuracy: 0.6500
# Epoch 26/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.2864 - categorical_accuracy: 0.8964WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 10s 666ms/step - loss: 0.2832 - categorical_accuracy: 0.9000 - val_loss: 0.8656 - val_categorical_accuracy: 0.6750
# Epoch 27/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.2733 - categorical_accuracy: 0.9036WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 10s 660ms/step - loss: 0.2701 - categorical_accuracy: 0.9033 - val_loss: 0.9516 - val_categorical_accuracy: 0.6667
# Epoch 28/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.2422 - categorical_accuracy: 0.9357WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 10s 673ms/step - loss: 0.2462 - categorical_accuracy: 0.9367 - val_loss: 0.8690 - val_categorical_accuracy: 0.6417
# Epoch 29/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.2457 - categorical_accuracy: 0.9250WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 10s 687ms/step - loss: 0.2444 - categorical_accuracy: 0.9267 - val_loss: 0.8624 - val_categorical_accuracy: 0.6583
# Epoch 30/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.2540 - categorical_accuracy: 0.9214WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 10s 693ms/step - loss: 0.2515 - categorical_accuracy: 0.9200 - val_loss: 0.8786 - val_categorical_accuracy: 0.6833
# Epoch 31/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.2294 - categorical_accuracy: 0.9357WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 10s 680ms/step - loss: 0.2239 - categorical_accuracy: 0.9367 - val_loss: 0.9587 - val_categorical_accuracy: 0.6667
# Epoch 32/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.2384 - categorical_accuracy: 0.9250WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 10s 693ms/step - loss: 0.2431 - categorical_accuracy: 0.9200 - val_loss: 0.9129 - val_categorical_accuracy: 0.6750
# Epoch 33/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.1855 - categorical_accuracy: 0.9536WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 10s 687ms/step - loss: 0.2009 - categorical_accuracy: 0.9467 - val_loss: 0.9169 - val_categorical_accuracy: 0.6583
# Epoch 34/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.2003 - categorical_accuracy: 0.9393WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 10s 687ms/step - loss: 0.2048 - categorical_accuracy: 0.9400 - val_loss: 0.9351 - val_categorical_accuracy: 0.6583
# Epoch 35/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.1886 - categorical_accuracy: 0.9393WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 11s 713ms/step - loss: 0.1942 - categorical_accuracy: 0.9333 - val_loss: 0.9330 - val_categorical_accuracy: 0.6667
# Epoch 36/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.1959 - categorical_accuracy: 0.9500WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 10s 693ms/step - loss: 0.1903 - categorical_accuracy: 0.9533 - val_loss: 0.9323 - val_categorical_accuracy: 0.6833
# Epoch 37/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.1867 - categorical_accuracy: 0.9429WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 10s 693ms/step - loss: 0.1871 - categorical_accuracy: 0.9433 - val_loss: 0.9477 - val_categorical_accuracy: 0.6583
# Epoch 38/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.1819 - categorical_accuracy: 0.9536WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 10s 700ms/step - loss: 0.1848 - categorical_accuracy: 0.9500 - val_loss: 0.9590 - val_categorical_accuracy: 0.6667
# Epoch 39/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.1851 - categorical_accuracy: 0.9429WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 11s 713ms/step - loss: 0.1832 - categorical_accuracy: 0.9433 - val_loss: 0.9860 - val_categorical_accuracy: 0.6583
# Epoch 40/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.1798 - categorical_accuracy: 0.9536WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 10s 693ms/step - loss: 0.1790 - categorical_accuracy: 0.9533 - val_loss: 0.9453 - val_categorical_accuracy: 0.6750
# Epoch 41/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.1751 - categorical_accuracy: 0.9607WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 10s 700ms/step - loss: 0.1734 - categorical_accuracy: 0.9633 - val_loss: 1.0110 - val_categorical_accuracy: 0.6667
# Epoch 42/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.1625 - categorical_accuracy: 0.9607WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 10s 687ms/step - loss: 0.1672 - categorical_accuracy: 0.9567 - val_loss: 0.9572 - val_categorical_accuracy: 0.6583
# Epoch 43/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.1662 - categorical_accuracy: 0.9464WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 10s 699ms/step - loss: 0.1732 - categorical_accuracy: 0.9500 - val_loss: 1.0145 - val_categorical_accuracy: 0.6667
# Epoch 44/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.1705 - categorical_accuracy: 0.9500WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 10s 700ms/step - loss: 0.1647 - categorical_accuracy: 0.9533 - val_loss: 0.9834 - val_categorical_accuracy: 0.6667
# Epoch 45/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.1546 - categorical_accuracy: 0.9607WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 10s 680ms/step - loss: 0.1606 - categorical_accuracy: 0.9567 - val_loss: 1.0070 - val_categorical_accuracy: 0.6583
# Epoch 46/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.1619 - categorical_accuracy: 0.9536WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 10s 680ms/step - loss: 0.1603 - categorical_accuracy: 0.9567 - val_loss: 1.0006 - val_categorical_accuracy: 0.6667
# Epoch 47/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.1581 - categorical_accuracy: 0.9643WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 11s 706ms/step - loss: 0.1576 - categorical_accuracy: 0.9633 - val_loss: 0.9961 - val_categorical_accuracy: 0.6667
# Epoch 48/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.1552 - categorical_accuracy: 0.9607WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 10s 687ms/step - loss: 0.1533 - categorical_accuracy: 0.9600 - val_loss: 1.0212 - val_categorical_accuracy: 0.6667
# Epoch 49/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.1579 - categorical_accuracy: 0.9571WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 10s 680ms/step - loss: 0.1550 - categorical_accuracy: 0.9567 - val_loss: 1.0068 - val_categorical_accuracy: 0.6583
# Epoch 50/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.1558 - categorical_accuracy: 0.9679WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 10s 687ms/step - loss: 0.1500 - categorical_accuracy: 0.9700 - val_loss: 1.0106 - val_categorical_accuracy: 0.6750

# %% [markdown]
# #### Plot the learning curves

# %%
# Run this cell to plot accuracy vs epoch and loss vs epoch

plt.figure(figsize=(15,5))
plt.subplot(121)
try:
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
except KeyError:
    try:
        plt.plot(history.history['acc'])
        plt.plot(history.history['val_acc'])
    except KeyError:
        plt.plot(history.history['categorical_accuracy'])
        plt.plot(history.history['val_categorical_accuracy'])

plt.title('Accuracy vs. epochs')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Training', 'Validation'], loc='lower right')

plt.subplot(122)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Loss vs. epochs')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Training', 'Validation'], loc='upper right')
plt.show()

# %% [markdown]
# You may notice overfitting in the above plots, through a growing discrepancy between the training and validation loss and accuracy. We will aim to mitigate this using data augmentation. Given our limited dataset, we may be able to improve the performance by applying random modifications to the images in the training data, effectively increasing the size of the dataset.

# %% [markdown]
# #### Create a new data generator with data augmentation
#
# You should now write a function to create a new `ImageDataGenerator` object, which performs the following data preprocessing and augmentation:
#
# * Scales the image pixel values by a factor of 1/255.
# * Randomly rotates images by up to 30 degrees
# * Randomly alters the brightness (picks a brightness shift value) from the range (0.5, 1.5)
# * Randomly flips images horizontally
#
# Hint: you may need to refer to the [documentation](https://keras.io/preprocessing/image/#imagedatagenerator-class) for the `ImageDataGenerator`.

# %%
#### GRADED CELL ####

# Complete the following function. 
# Make sure to not change the function name or arguments.    
    
def get_ImageDataGenerator_augmented():
    """
    This function should return an instance of the ImageDataGenerator class 
    with the above specifications.
    """
    
    from tensorflow.keras.preprocessing.image import ImageDataGenerator  
    return ImageDataGenerator(rescale = 1.0/255, rotation_range = 30, brightness_range = (0.5, 1.5), horizontal_flip = True)

# %%
# Call the function to get an ImageDataGenerator as specified

image_gen_aug = get_ImageDataGenerator_augmented()

# %%
# Run this cell to define training and validation generators 

valid_generator_aug = get_generator(image_gen_aug, valid_dir)
train_generator_aug = get_generator(image_gen_aug, train_dir, seed=10)
# Out:
# Found 120 images belonging to 3 classes.
# Found 300 images belonging to 3 classes.

# %%
# Reset the original train_generator with the same random seed

train_generator = get_generator(image_gen, train_dir, seed=10)
# Out:
# Found 300 images belonging to 3 classes.

# %% [markdown]
# #### Display sample augmented images and labels from the training set
#
# The following cell depends on your function `get_generator` to be implemented correctly. If it raises an error, go back and check the function specifications carefully.
#
# The cell will display augmented and non-augmented images (and labels) from the training dataset, using the `train_generator_aug` and `train_generator` objects defined above (if the images do not correspond to each other, check you have implemented the `seed` argument correctly).

# %%
# Display a few images and labels from the non-augmented and augmented generators

batch = next(train_generator)
batch_images = np.array(batch[0])
batch_labels = np.array(batch[1])

aug_batch = next(train_generator_aug)
aug_batch_images = np.array(aug_batch[0])
aug_batch_labels = np.array(aug_batch[1])

plt.figure(figsize=(16,5))
plt.suptitle("Unaugmented images", fontsize=16)
for n, i in enumerate(np.arange(10)):
    ax = plt.subplot(2, 5, n+1)
    plt.imshow(batch_images[i])
    plt.title(lsun_classes[np.where(batch_labels[i] == 1.)[0][0]])
    plt.axis('off')
plt.figure(figsize=(16,5))
plt.suptitle("Augmented images", fontsize=16)
for n, i in enumerate(np.arange(10)):
    ax = plt.subplot(2, 5, n+1)
    plt.imshow(aug_batch_images[i])
    plt.title(lsun_classes[np.where(aug_batch_labels[i] == 1.)[0][0]])
    plt.axis('off')

# %%
# Reset the augmented data generator

train_generator_aug = get_generator(image_gen_aug, train_dir)
# Out:
# Found 300 images belonging to 3 classes.

# %% [markdown]
# #### Train a new model on the augmented dataset

# %%
# Build and compile a new model

lsun_new_model = get_model((64, 64, 3))

# %%
# Train the model

history_augmented = train_model(lsun_new_model, train_generator_aug, valid_generator_aug, epochs=50)
# Out:
# Epoch 1/50
# 14/15 [===========================>..] - ETA: 0s - loss: 1.1312 - categorical_accuracy: 0.3393WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 12s 823ms/step - loss: 1.1307 - categorical_accuracy: 0.3367 - val_loss: 1.0870 - val_categorical_accuracy: 0.4083
# Epoch 2/50
# 14/15 [===========================>..] - ETA: 0s - loss: 1.0949 - categorical_accuracy: 0.3964WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 12s 780ms/step - loss: 1.0940 - categorical_accuracy: 0.3967 - val_loss: 1.0884 - val_categorical_accuracy: 0.4500
# Epoch 3/50
# 14/15 [===========================>..] - ETA: 0s - loss: 1.0898 - categorical_accuracy: 0.4393WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 11s 766ms/step - loss: 1.0903 - categorical_accuracy: 0.4400 - val_loss: 1.0819 - val_categorical_accuracy: 0.4083
# Epoch 4/50
# 14/15 [===========================>..] - ETA: 0s - loss: 1.0670 - categorical_accuracy: 0.4964WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 12s 774ms/step - loss: 1.0657 - categorical_accuracy: 0.4933 - val_loss: 1.0499 - val_categorical_accuracy: 0.4417
# Epoch 5/50
# 14/15 [===========================>..] - ETA: 0s - loss: 1.0407 - categorical_accuracy: 0.4821WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 12s 786ms/step - loss: 1.0412 - categorical_accuracy: 0.4767 - val_loss: 0.9612 - val_categorical_accuracy: 0.6083
# Epoch 6/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.9637 - categorical_accuracy: 0.5929WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 12s 787ms/step - loss: 0.9698 - categorical_accuracy: 0.5900 - val_loss: 0.9185 - val_categorical_accuracy: 0.5833
# Epoch 7/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.8924 - categorical_accuracy: 0.6143WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 12s 793ms/step - loss: 0.8907 - categorical_accuracy: 0.6133 - val_loss: 0.9382 - val_categorical_accuracy: 0.5250
# Epoch 8/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.8456 - categorical_accuracy: 0.6357WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 12s 813ms/step - loss: 0.8414 - categorical_accuracy: 0.6300 - val_loss: 0.8284 - val_categorical_accuracy: 0.5833
# Epoch 9/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.7961 - categorical_accuracy: 0.6786WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 12s 807ms/step - loss: 0.7940 - categorical_accuracy: 0.6733 - val_loss: 0.7379 - val_categorical_accuracy: 0.6833
# Epoch 10/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.6995 - categorical_accuracy: 0.6964WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 12s 767ms/step - loss: 0.7007 - categorical_accuracy: 0.6933 - val_loss: 0.7719 - val_categorical_accuracy: 0.6333
# Epoch 11/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.7086 - categorical_accuracy: 0.6893WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 12s 820ms/step - loss: 0.7179 - categorical_accuracy: 0.6833 - val_loss: 0.7236 - val_categorical_accuracy: 0.6250
# Epoch 12/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.7078 - categorical_accuracy: 0.6786WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 12s 780ms/step - loss: 0.7005 - categorical_accuracy: 0.6867 - val_loss: 0.7324 - val_categorical_accuracy: 0.6167
# Epoch 13/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.6881 - categorical_accuracy: 0.6964WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 12s 780ms/step - loss: 0.7026 - categorical_accuracy: 0.6933 - val_loss: 0.7718 - val_categorical_accuracy: 0.6583
# Epoch 14/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.6801 - categorical_accuracy: 0.7250WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 12s 793ms/step - loss: 0.6856 - categorical_accuracy: 0.7233 - val_loss: 0.7490 - val_categorical_accuracy: 0.6417
# Epoch 15/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.6626 - categorical_accuracy: 0.7036WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 12s 800ms/step - loss: 0.6581 - categorical_accuracy: 0.7067 - val_loss: 0.7532 - val_categorical_accuracy: 0.6333
# Epoch 16/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.6601 - categorical_accuracy: 0.7393WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 12s 806ms/step - loss: 0.6673 - categorical_accuracy: 0.7367 - val_loss: 0.7740 - val_categorical_accuracy: 0.6083
# Epoch 17/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.6910 - categorical_accuracy: 0.6821WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 12s 780ms/step - loss: 0.6824 - categorical_accuracy: 0.6967 - val_loss: 0.7905 - val_categorical_accuracy: 0.6000
# Epoch 18/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.6400 - categorical_accuracy: 0.7179WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 12s 767ms/step - loss: 0.6436 - categorical_accuracy: 0.7167 - val_loss: 0.7037 - val_categorical_accuracy: 0.7083
# Epoch 19/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.6279 - categorical_accuracy: 0.7571WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 12s 773ms/step - loss: 0.6332 - categorical_accuracy: 0.7500 - val_loss: 0.7335 - val_categorical_accuracy: 0.6667
# Epoch 20/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.5920 - categorical_accuracy: 0.7607WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 12s 773ms/step - loss: 0.5931 - categorical_accuracy: 0.7600 - val_loss: 0.7023 - val_categorical_accuracy: 0.6917
# Epoch 21/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.6608 - categorical_accuracy: 0.7036WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 12s 786ms/step - loss: 0.6529 - categorical_accuracy: 0.7133 - val_loss: 0.7357 - val_categorical_accuracy: 0.6500
# Epoch 22/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.5875 - categorical_accuracy: 0.7464WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 12s 767ms/step - loss: 0.6172 - categorical_accuracy: 0.7267 - val_loss: 0.7502 - val_categorical_accuracy: 0.6333
# Epoch 23/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.5717 - categorical_accuracy: 0.7500WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 11s 760ms/step - loss: 0.5793 - categorical_accuracy: 0.7467 - val_loss: 0.7321 - val_categorical_accuracy: 0.6500
# Epoch 24/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.5771 - categorical_accuracy: 0.7571WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 12s 767ms/step - loss: 0.5847 - categorical_accuracy: 0.7567 - val_loss: 0.7418 - val_categorical_accuracy: 0.6667
# Epoch 25/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.5613 - categorical_accuracy: 0.7536WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 12s 780ms/step - loss: 0.5620 - categorical_accuracy: 0.7600 - val_loss: 0.7317 - val_categorical_accuracy: 0.6333
# Epoch 26/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.6191 - categorical_accuracy: 0.7321WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 11s 760ms/step - loss: 0.5972 - categorical_accuracy: 0.7467 - val_loss: 0.7545 - val_categorical_accuracy: 0.6667
# Epoch 27/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.5753 - categorical_accuracy: 0.7214WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 11s 760ms/step - loss: 0.5788 - categorical_accuracy: 0.7233 - val_loss: 0.7493 - val_categorical_accuracy: 0.6750
# Epoch 28/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.5503 - categorical_accuracy: 0.7821WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 11s 760ms/step - loss: 0.5483 - categorical_accuracy: 0.7800 - val_loss: 0.7432 - val_categorical_accuracy: 0.6333
# Epoch 29/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.5576 - categorical_accuracy: 0.7821WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 12s 780ms/step - loss: 0.5604 - categorical_accuracy: 0.7800 - val_loss: 0.7759 - val_categorical_accuracy: 0.6917
# Epoch 30/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.5573 - categorical_accuracy: 0.7643WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 12s 773ms/step - loss: 0.5586 - categorical_accuracy: 0.7667 - val_loss: 0.7708 - val_categorical_accuracy: 0.6667
# Epoch 31/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.5750 - categorical_accuracy: 0.7393WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 11s 767ms/step - loss: 0.5747 - categorical_accuracy: 0.7400 - val_loss: 0.7669 - val_categorical_accuracy: 0.6500
# Epoch 32/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.6015 - categorical_accuracy: 0.7286WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 12s 793ms/step - loss: 0.5941 - categorical_accuracy: 0.7333 - val_loss: 0.6682 - val_categorical_accuracy: 0.6833
# Epoch 33/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.5400 - categorical_accuracy: 0.7679WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 11s 766ms/step - loss: 0.5550 - categorical_accuracy: 0.7667 - val_loss: 0.7271 - val_categorical_accuracy: 0.6333
# Epoch 34/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.5335 - categorical_accuracy: 0.7679WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 12s 786ms/step - loss: 0.5528 - categorical_accuracy: 0.7533 - val_loss: 0.7235 - val_categorical_accuracy: 0.6250
# Epoch 35/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.5207 - categorical_accuracy: 0.7714WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 11s 754ms/step - loss: 0.5208 - categorical_accuracy: 0.7700 - val_loss: 0.7231 - val_categorical_accuracy: 0.6333
# Epoch 36/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.5235 - categorical_accuracy: 0.7679WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 12s 773ms/step - loss: 0.5359 - categorical_accuracy: 0.7667 - val_loss: 0.7579 - val_categorical_accuracy: 0.6750
# Epoch 37/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.5429 - categorical_accuracy: 0.7964WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 12s 780ms/step - loss: 0.5527 - categorical_accuracy: 0.7933 - val_loss: 0.7668 - val_categorical_accuracy: 0.6583
# Epoch 38/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.5084 - categorical_accuracy: 0.7929WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 12s 780ms/step - loss: 0.5271 - categorical_accuracy: 0.7933 - val_loss: 0.7608 - val_categorical_accuracy: 0.6417
# Epoch 39/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.5372 - categorical_accuracy: 0.7429WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 12s 774ms/step - loss: 0.5357 - categorical_accuracy: 0.7500 - val_loss: 0.6963 - val_categorical_accuracy: 0.6583
# Epoch 40/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.5155 - categorical_accuracy: 0.7571WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 12s 786ms/step - loss: 0.5214 - categorical_accuracy: 0.7600 - val_loss: 0.7305 - val_categorical_accuracy: 0.6833
# Epoch 41/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.5491 - categorical_accuracy: 0.7857WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 11s 766ms/step - loss: 0.5499 - categorical_accuracy: 0.7767 - val_loss: 0.7730 - val_categorical_accuracy: 0.6583
# Epoch 42/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.5561 - categorical_accuracy: 0.7643WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 12s 787ms/step - loss: 0.5386 - categorical_accuracy: 0.7733 - val_loss: 0.7278 - val_categorical_accuracy: 0.6333
# Epoch 43/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.5380 - categorical_accuracy: 0.7571WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 11s 766ms/step - loss: 0.5449 - categorical_accuracy: 0.7567 - val_loss: 0.7529 - val_categorical_accuracy: 0.6917
# Epoch 44/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.4916 - categorical_accuracy: 0.7857WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 12s 773ms/step - loss: 0.4938 - categorical_accuracy: 0.7867 - val_loss: 0.7085 - val_categorical_accuracy: 0.6667
# Epoch 45/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.5259 - categorical_accuracy: 0.7857WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 11s 760ms/step - loss: 0.5171 - categorical_accuracy: 0.7900 - val_loss: 0.7384 - val_categorical_accuracy: 0.6833
# Epoch 46/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.5151 - categorical_accuracy: 0.7964WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 11s 760ms/step - loss: 0.5208 - categorical_accuracy: 0.7867 - val_loss: 0.7254 - val_categorical_accuracy: 0.6833
# Epoch 47/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.4927 - categorical_accuracy: 0.7893WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 12s 780ms/step - loss: 0.4868 - categorical_accuracy: 0.7867 - val_loss: 0.7413 - val_categorical_accuracy: 0.6917
# Epoch 48/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.5209 - categorical_accuracy: 0.7643WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 11s 753ms/step - loss: 0.5049 - categorical_accuracy: 0.7700 - val_loss: 0.7164 - val_categorical_accuracy: 0.6667
# Epoch 49/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.5037 - categorical_accuracy: 0.8000WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 11s 767ms/step - loss: 0.5063 - categorical_accuracy: 0.7967 - val_loss: 0.7870 - val_categorical_accuracy: 0.6583
# Epoch 50/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.5437 - categorical_accuracy: 0.7821WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 12s 780ms/step - loss: 0.5303 - categorical_accuracy: 0.7900 - val_loss: 0.7206 - val_categorical_accuracy: 0.7000

# %% [markdown]
# #### Plot the learning curves

# %%
# Run this cell to plot accuracy vs epoch and loss vs epoch

plt.figure(figsize=(15,5))
plt.subplot(121)
try:
    plt.plot(history_augmented.history['accuracy'])
    plt.plot(history_augmented.history['val_accuracy'])
except KeyError:
    try:
        plt.plot(history_augmented.history['acc'])
        plt.plot(history_augmented.history['val_acc'])
    except KeyError:
        plt.plot(history_augmented.history['categorical_accuracy'])
        plt.plot(history_augmented.history['val_categorical_accuracy'])
plt.title('Accuracy vs. epochs')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Training', 'Validation'], loc='lower right')

plt.subplot(122)
plt.plot(history_augmented.history['loss'])
plt.plot(history_augmented.history['val_loss'])
plt.title('Loss vs. epochs')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Training', 'Validation'], loc='upper right')
plt.show()

# %% [markdown]
# Do you see an improvement in the overfitting? This will of course vary based on your particular run and whether you have altered the hyperparameters.

# %% [markdown]
# #### Get predictions using the trained model

# %%
# Get model predictions for the first 3 batches of test data

num_batches = 3
seed = 25
test_generator = get_generator(image_gen_aug, test_dir, seed=seed)
predictions = lsun_new_model.predict_generator(test_generator, steps=num_batches)
# Out:
# Found 300 images belonging to 3 classes.

# %%
# Run this cell to view randomly selected images and model predictions

# Get images and ground truth labels
test_generator = get_generator(image_gen_aug, test_dir, seed=seed)
batches = []
for i in range(num_batches):
    batches.append(next(test_generator))
    
batch_images = np.vstack([b[0] for b in batches])
batch_labels = np.concatenate([b[1].astype(np.int32) for b in batches])

# Randomly select images from the batch
inx = np.random.choice(predictions.shape[0], 4, replace=False)
print(inx)

fig, axes = plt.subplots(4, 2, figsize=(16, 12))
fig.subplots_adjust(hspace=0.4, wspace=-0.2)

for n, i in enumerate(inx):
    axes[n, 0].imshow(batch_images[i])
    axes[n, 0].get_xaxis().set_visible(False)
    axes[n, 0].get_yaxis().set_visible(False)
    axes[n, 0].text(30., -3.5, lsun_classes[np.where(batch_labels[i] == 1.)[0][0]], 
                    horizontalalignment='center')
    axes[n, 1].bar(np.arange(len(predictions[i])), predictions[i])
    axes[n, 1].set_xticks(np.arange(len(predictions[i])))
    axes[n, 1].set_xticklabels(lsun_classes)
    axes[n, 1].set_title(f"Categorical distribution. Model prediction: {lsun_classes[np.argmax(predictions[i])]}")
    
plt.show()
# Out:
# Found 300 images belonging to 3 classes.
# [26 14 27 55]

# %% [markdown]
# Congratulations! This completes the first part of the programming assignment using the tf.keras image data processing tools.

# %% [markdown]
# ### Part 2: tf.data
#
# ![CIFAR-100 overview image](data/cifar100/cifar100.png)
#
# #### The CIFAR-100 Dataset

# %% [markdown]
# In the second part of this assignment, you will use the [CIFAR-100 dataset](https://www.cs.toronto.edu/~kriz/cifar.html). This image dataset has 100 classes with 500 training images and 100 test images per class.
#
# * A. Krizhevsky. "Learning Multiple Layers of Features from Tiny Images". April 2009
#
# Your goal is to use the tf.data module preprocessing tools to construct a data ingestion pipeline including filtering and function mapping over the dataset to train a neural network to classify the images.

# %% [markdown]
# #### Load the dataset

# %%
# Load the data, along with the labels

(train_data, train_labels), (test_data, test_labels) = cifar100.load_data(label_mode='fine')
with open('data/cifar100/cifar100_labels.json', 'r') as j:
    cifar_labels = json.load(j)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-100-python.tar.gz
# 169009152/169001437 [==============================] - 3s 0us/step

# %% [markdown]
# #### Display sample images and labels from the training set

# %%
# Display a few images and labels

plt.figure(figsize=(15,8))
inx = np.random.choice(train_data.shape[0], 32, replace=False)
for n, i in enumerate(inx):
    ax = plt.subplot(4, 8, n+1)
    plt.imshow(train_data[i])
    plt.title(cifar_labels[int(train_labels[i])])
    plt.axis('off')

# %% [markdown]
# #### Create Dataset objects for the train and test images
#
# You should now write a function to create a `tf.data.Dataset` object for each of the training and test images and labels. This function should take a numpy array of images in the first argument and a numpy array of labels in the second argument, and create a `Dataset` object.
#
# Your function should then return the `Dataset` object. Do not batch or shuffle the `Dataset` (this will be done later).

# %%
#### GRADED CELL ####

# Complete the following function. 
# Make sure to not change the function name or arguments.

def create_dataset(data, labels):
    """
    This function takes a numpy array batch of images in the first argument, and
    a corresponding array containing the labels in the second argument.
    The function should then create a tf.data.Dataset object with these inputs
    and outputs, and return it.
    """
    return tf.data.Dataset.from_tensor_slices((data, labels))

# %%
# Run the below cell to convert the training and test data and labels into datasets

train_dataset = create_dataset(train_data, train_labels)
test_dataset = create_dataset(test_data, test_labels)

# %%
# Check the element_spec of your datasets

print(train_dataset.element_spec)
print(test_dataset.element_spec)
# Out:
# (TensorSpec(shape=(32, 32, 3), dtype=tf.uint8, name=None), TensorSpec(shape=(1,), dtype=tf.int64, name=None))
# (TensorSpec(shape=(32, 32, 3), dtype=tf.uint8, name=None), TensorSpec(shape=(1,), dtype=tf.int64, name=None))

# %% [markdown]
# #### Filter the Dataset
#
# Write a function to filter the train and test datasets so that they only generate images that belong to a specified set of classes.
#
# The function should take a `Dataset` object in the first argument, and a list of integer class indices in the second argument. Inside your function you should define an auxiliary function that you will use with the `filter` method of the `Dataset` object. This auxiliary function should take image and label arguments (as in the `element_spec`) for a single element in the batch, and return a boolean indicating if the label is one of the allowed classes.
#
# Your function should then return the filtered dataset.
#
# **Hint:** you may need to use the [`tf.equal`](https://www.tensorflow.org/api_docs/python/tf/math/equal), [`tf.cast`](https://www.tensorflow.org/api_docs/python/tf/dtypes/cast) and [`tf.math.reduce_any`](https://www.tensorflow.org/api_docs/python/tf/math/reduce_any) functions in your auxiliary function.

# %%
#### GRADED CELL ####

# Complete the following function. 
# Make sure to not change the function name or arguments.


import tensorflow as tf
def filter_classes(dataset, classes):
    """
    This function should filter the dataset by only retaining dataset elements whose
    label belongs to one of the integers in the classes list.
    The function should then return the filtered Dataset object.
    """
    
    foo = lambda x,y: tf.reduce_any(tf.equal(y, classes ))
    
    return dataset.filter(foo)

# %%
# Run the below cell to filter the datasets using your function

cifar_classes = [0, 29, 99] # Your datasets should contain only classes in this list


train_dataset = filter_classes(train_dataset, cifar_classes)
test_dataset = filter_classes(test_dataset, cifar_classes)

# %% [markdown]
# #### Apply map functions to the Dataset
#
# You should now write two functions that use the `map` method to process the images and labels in the filtered dataset.
#
# The first function should one-hot encode the remaining labels so that we can train the network using a categorical cross entropy loss.
#
# The function should take a `Dataset` object as an argument. Inside your function you should define an auxiliary function that you will use with the `map` method of the `Dataset` object. This auxiliary function should take image and label arguments (as in the `element_spec`) for a single element in the batch, and return a tuple of two elements, with the unmodified image in the first element, and a one-hot vector in the second element. The labels should be encoded according to the following:
#
# * Class 0 maps to `[1., 0., 0.]`
# * Class 29 maps to `[0., 1., 0.]`
# * Class 99 maps to `[0., 0., 1.]`
#
# Your function should then return the mapped dataset.

# %%
#### GRADED CELL ####

# Complete the following function. 
# Make sure to not change the function name or arguments.

def map_labels(dataset):
    """
    This function should map over the dataset to convert the label to a 
    one-hot vector. The encoding should be done according to the above specification.
    The function should then return the mapped Dataset object.
    """
    def map_fun(x,y):
        if y == tf.constant(0, dtype = tf.int64):
            return (x,tf.constant([1., 0., 0.], dtype = tf.float32))
        
        if y == tf.constant(29, dtype = tf.int64):
            return (x,tf.constant([0., 1., 0.], dtype = tf.float32))
        
        if y == tf.constant(99, dtype = tf.int64):
            return (x,tf.constant([0., 0., 1.], dtype = tf.float32))
        
        return (x, tf.constant([0., 0., 0.]))
                    
    
    return dataset.map(map_fun)

# %%
# Run the below cell to one-hot encode the training and test labels.

train_dataset = map_labels(train_dataset)
test_dataset = map_labels(test_dataset)

# %% [markdown]
# The second function should process the images according to the following specification:
#
# * Rescale the image pixel values by a factor of 1/255.
# * Convert the colour images (3 channels) to black and white images (single channel) by computing the average pixel value across all channels.
#
# The function should take a `Dataset` object as an argument. Inside your function you should again define an auxiliary function that you will use with the `map` method of the `Dataset` object. This auxiliary function should take image and label arguments (as in the `element_spec`) for a single element in the batch, and return a tuple of two elements, with the processed image in the first element, and the unmodified label in the second argument.
#
# Your function should then return the mapped dataset.
#
# **Hint:** you may find it useful to use [`tf.reduce_mean`](https://www.tensorflow.org/api_docs/python/tf/math/reduce_mean?version=stable) since the black and white image is the colour-average of the colour images. You can also use the `keepdims` keyword in `tf.reduce_mean` to retain the single colour channel.

# %%
#### GRADED CELL ####

# Complete the following function. 
# Make sure to not change the function name or arguments.

def map_images(dataset):
    """
    This function should map over the dataset to process the image according to the 
    above specification. The function should then return the mapped Dataset object.
    """
    def mapping_fun(x,y):
        x = tf.cast(x, tf.float32)
        return (tf.reduce_mean(x * 1.0 / 255, axis = 2, keepdims = True),y)
    
    return dataset.map(mapping_fun)

# %%
# Run the below cell to apply your mapping function to the datasets

train_dataset_bw = map_images(train_dataset)
test_dataset_bw = map_images(test_dataset)

# %% [markdown]
# #### Display a batch of processed images

# %%
# Run this cell to view a selection of images before and after processing

plt.figure(figsize=(16,5))
plt.suptitle("Unprocessed images", fontsize=16)
for n, elem in enumerate(train_dataset.take(10)):
    images, labels = elem
    ax = plt.subplot(2, 5, n+1)
    plt.title(cifar_labels[cifar_classes[np.where(labels == 1.)[0][0]]])
    plt.imshow(np.squeeze(images), cmap='gray')
    plt.axis('off')
    
plt.figure(figsize=(16,5))
plt.suptitle("Processed images", fontsize=16)
for n, elem in enumerate(train_dataset_bw.take(10)):
    images_bw, labels_bw = elem
    ax = plt.subplot(2, 5, n+1)
    plt.title(cifar_labels[cifar_classes[np.where(labels_bw == 1.)[0][0]]])
    plt.imshow(np.squeeze(images_bw), cmap='gray')
    plt.axis('off')

# %% [markdown]
# We will now batch and shuffle the Dataset objects.

# %%
# Run the below cell to batch the training dataset and expand the final dimensinos

train_dataset_bw = train_dataset_bw.batch(10)
train_dataset_bw = train_dataset_bw.shuffle(100)

test_dataset_bw = test_dataset_bw.batch(10)
test_dataset_bw = test_dataset_bw.shuffle(100)

# %% [markdown]
# #### Train a neural network model
#
# Now we will train a model using the `Dataset` objects. We will use the model specification and function from the first part of this assignment, only modifying the size of the input images.

# %%
# Build and compile a new model with our original spec, using the new image size
    
cifar_model = get_model((32, 32, 1))

# %%
# Train the model for 15 epochs

history = cifar_model.fit(train_dataset_bw, validation_data=test_dataset_bw, epochs=15)
# Out:
# Epoch 1/15
# 150/150 [==============================] - 23s 152ms/step - loss: 1.0559 - categorical_accuracy: 0.4540 - val_loss: 0.0000e+00 - val_categorical_accuracy: 0.0000e+00
# Epoch 2/15
# 150/150 [==============================] - 20s 135ms/step - loss: 0.9102 - categorical_accuracy: 0.5980 - val_loss: 0.8935 - val_categorical_accuracy: 0.5233
# Epoch 3/15
# 150/150 [==============================] - 21s 140ms/step - loss: 0.8184 - categorical_accuracy: 0.6347 - val_loss: 0.7749 - val_categorical_accuracy: 0.6533
# Epoch 4/15
# 150/150 [==============================] - 21s 140ms/step - loss: 0.7421 - categorical_accuracy: 0.6740 - val_loss: 0.7400 - val_categorical_accuracy: 0.6733
# Epoch 5/15
# 150/150 [==============================] - 21s 138ms/step - loss: 0.6916 - categorical_accuracy: 0.7013 - val_loss: 0.7022 - val_categorical_accuracy: 0.7500
# Epoch 6/15
# 150/150 [==============================] - 21s 139ms/step - loss: 0.6518 - categorical_accuracy: 0.7240 - val_loss: 0.6864 - val_categorical_accuracy: 0.7300
# Epoch 7/15
# 150/150 [==============================] - 21s 141ms/step - loss: 0.6207 - categorical_accuracy: 0.7387 - val_loss: 0.6834 - val_categorical_accuracy: 0.7467
# Epoch 8/15
# 150/150 [==============================] - 22s 144ms/step - loss: 0.5931 - categorical_accuracy: 0.7687 - val_loss: 0.6779 - val_categorical_accuracy: 0.7633
# Epoch 9/15
# 150/150 [==============================] - 21s 140ms/step - loss: 0.5758 - categorical_accuracy: 0.7593 - val_loss: 0.7044 - val_categorical_accuracy: 0.6967
# Epoch 10/15
# 150/150 [==============================] - 21s 139ms/step - loss: 0.5489 - categorical_accuracy: 0.7787 - val_loss: 0.6298 - val_categorical_accuracy: 0.7533
# Epoch 11/15
# 150/150 [==============================] - 21s 139ms/step - loss: 0.5382 - categorical_accuracy: 0.7780 - val_loss: 0.6125 - val_categorical_accuracy: 0.7767
# Epoch 12/15
# 150/150 [==============================] - 21s 140ms/step - loss: 0.5205 - categorical_accuracy: 0.7953 - val_loss: 0.5782 - val_categorical_accuracy: 0.7867
# Epoch 13/15
# 150/150 [==============================] - 21s 138ms/step - loss: 0.4834 - categorical_accuracy: 0.8153 - val_loss: 0.5741 - val_categorical_accuracy: 0.7900
# Epoch 14/15
# 150/150 [==============================] - 21s 139ms/step - loss: 0.4801 - categorical_accuracy: 0.8107 - val_loss: 0.5677 - val_categorical_accuracy: 0.7833
# Epoch 15/15
# 150/150 [==============================] - 21s 139ms/step - loss: 0.4713 - categorical_accuracy: 0.8193 - val_loss: 0.5602 - val_categorical_accuracy: 0.8100

# %% [markdown]
# #### Plot the learning curves

# %%
# Run this cell to plot accuracy vs epoch and loss vs epoch

plt.figure(figsize=(15,5))
plt.subplot(121)
try:
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
except KeyError:
    try:
        plt.plot(history.history['acc'])
        plt.plot(history.history['val_acc'])
    except KeyError:
        plt.plot(history.history['categorical_accuracy'])
        plt.plot(history.history['val_categorical_accuracy'])
plt.title('Accuracy vs. epochs')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Training', 'Validation'], loc='lower right')

plt.subplot(122)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Loss vs. epochs')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Training', 'Validation'], loc='upper right')
plt.show()

# %%
# Create an iterable from the batched test dataset

test_dataset = test_dataset.batch(10)
iter_test_dataset = iter(test_dataset)

# %%
# Display model predictions for a sample of test images

plt.figure(figsize=(15,8))
inx = np.random.choice(test_data.shape[0], 18, replace=False)
images, labels = next(iter_test_dataset)
probs = cifar_model(tf.reduce_mean(tf.cast(images, tf.float32), axis=-1, keepdims=True) / 255.)
preds = np.argmax(probs, axis=1)
for n in range(10):
    ax = plt.subplot(2, 5, n+1)
    plt.imshow(images[n])
    plt.title(cifar_labels[cifar_classes[np.where(labels[n].numpy() == 1.0)[0][0]]])
    plt.text(0, 35, "Model prediction: {}".format(cifar_labels[cifar_classes[preds[n]]]))
    plt.axis('off')

# %% [markdown]
# Congratulations for completing this programming assignment! In the next week of the course we will learn to develop models for sequential data.
